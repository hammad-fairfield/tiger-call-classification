# %%
import os
import time
import noisereduce as nr
from scipy.io import wavfile
import matplotlib.pyplot as plt

import librosa
import librosa.display

from pydub import AudioSegment 
from pydub.utils import make_chunks

# %%
def process_audio(filename):
    myaudio = AudioSegment.from_file(filename, "wav") 
    chunk_length_ms = 3000
    chunks = make_chunks(myaudio,chunk_length_ms)  
    for i, chunk in enumerate(chunks):
        filename = os.path.splitext(filename)[0]
        chunk_name = './chunked/' + filename + "_{0}.wav".format(i) 
        chunk.export(chunk_name, format="wav")

def eliminate_noise(path, filename):
    audio, sample_rate = librosa.load(path)
    reduced_noise = nr.reduce_noise(y=audio, sr=sample_rate)
    filename = os.path.splitext(filename)[0]
    wavfile.write('./reduced/' + filename + "_reduced.wav", sample_rate, reduced_noise)

def convert_to_spec(path, filename):
    x, sr = librosa.load(path)
    filename = os.path.splitext(filename)[0]
    fname = './images/' + filename + '.png'
    X = librosa.stft(x)
    Xdb = librosa.amplitude_to_db(abs(X))
    fig = plt.figure(frameon = False)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    fin = librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    fig.savefig(fname, dpi='figure')
    plt.close();

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abs\\Documents\\ml-audio'

# %%
cwd = os.listdir('data')

for folder in cwd:
    
    data_path = './data/'+folder
    os.chdir(data_path)
    
    try:
        os.makedirs('chunked')
        os.makedirs('reduced')
        os.makedirs('images')
    except:
        pass
    
    #start_time = time.perf_counter()
    
    audio_file = os.listdir()
    for file in audio_file:
        if ('.wav' in file):
            process_audio(file)
    print("Audio Splitting Complete")
    
    #print(time.perf_counter() - start_time, "seconds")
    
    #start_time = time.perf_counter()
    
    chunked_files = os.listdir('chunked')
    for file in chunked_files:
        path = "./chunked/"+ file
        eliminate_noise(path, file)
    print("Eliminated Noise")
    
    #print(time.perf_counter() - start_time, "seconds")
    
    #start_time = time.perf_counter()
    
    reduced_files = os.listdir('reduced')
    for file in reduced_files:
        path = "./reduced/"+ file
        convert_to_spec(path, file)
    print("Spectrograms Generated")
    
    #print(time.perf_counter() - start_time, "seconds")
    
    os.chdir('../') 
    os.chdir('../') 

print("Preprocessing Complete")
# Out:
# Audio Splitting Complete
# Eliminated Noise
# Spectrograms Generated
# Audio Splitting Complete
# Eliminated Noise
# Spectrograms Generated
# Audio Splitting Complete
# Eliminated Noise
# Spectrograms Generated
# Audio Splitting Complete
# Eliminated Noise
# Spectrograms Generated
# Audio Splitting Complete
# Eliminated Noise
# Unexpected exception formatting exception. Falling back to standard exception
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000017D8AEFF670> (for post_execute):
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\abs\AppData\Local\Temp\ipykernel_3532\2268229381.py", line 40, in <module>
#     convert_to_spec(path, file)
#   File "C:\Users\abs\AppData\Local\Temp\ipykernel_3532\320422745.py", line 27, in convert_to_spec
#     fig.savefig(fname, dpi='figure')
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\figure.py", line 3058, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\backend_bases.py", line 2319, in print_figure
#     result = print_method(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\backend_bases.py", line 1648, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\_api\deprecation.py", line 415, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\backends\backend_agg.py", line 540, in print_png
#     FigureCanvasAgg.draw(self)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\backends\backend_agg.py", line 436, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 74, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\figure.py", line 2845, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\image.py", line 132, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\axes\_base.py", line 3091, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\image.py", line 132, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\collections.py", line 2175, in draw
#     self.update_scalarmappable()
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\collections.py", line 905, in update_scalarmappable
#     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\cm.py", line 456, in to_rgba
#     rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\colors.py", line 642, in __call__
#     lut.take(xa, axis=0, mode='clip', out=rgba)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.02 MiB for an array with shape (133250,) and data type int64
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 793, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 848, in get_records
#     return list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 583, in stack_data
#     yield from collapse_repeated(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 573, in mapper
#     return cls(f, options)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 537, in __init__
#     self.executing = Source.executing(frame_or_tb)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 359, in executing
#     source = cls.for_frame(frame)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 277, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 306, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 317, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 257, in __init__
#     self.tree = ast.parse(ast_text, filename=filename)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
# MemoryError
# Traceback (most recent call last):
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\events.py", line 89, in trigger
#     func(*args, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\pyplot.py", line 137, in post_execute
#     draw_all()
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\_pylab_helpers.py", line 141, in draw_all
#     manager.canvas.draw_idle()
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\backend_bases.py", line 2060, in draw_idle
#     self.draw(*args, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\backends\backend_agg.py", line 436, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 74, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\figure.py", line 2845, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\image.py", line 132, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\axes\_base.py", line 3091, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\image.py", line 132, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\collections.py", line 2175, in draw
#     self.update_scalarmappable()
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\collections.py", line 905, in update_scalarmappable
#     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\cm.py", line 455, in to_rgba
#     x = self.norm(x)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\colors.py", line 1236, in __call__
#     result, is_scalar = self.process_value(value)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\colors.py", line 1212, in process_value
#     result = np.ma.array(data, mask=mask, dtype=dtype, copy=True)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\numpy\ma\core.py", line 6562, in array
#     return MaskedArray(data, mask=mask, dtype=dtype, copy=copy,
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\numpy\ma\core.py", line 2826, in __new__
#     _data = np.array(data, dtype=dtype, copy=copy,
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 521. KiB for an array with shape (133250,) and data type float32
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 793, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 848, in get_records
#     return list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 583, in stack_data
#     yield from collapse_repeated(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 573, in mapper
#     return cls(f, options)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 537, in __init__
#     self.executing = Source.executing(frame_or_tb)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 359, in executing
#     source = cls.for_frame(frame)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 277, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 306, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 317, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 257, in __init__
#     self.tree = ast.parse(ast_text, filename=filename)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
# MemoryError
# Traceback (most recent call last):
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\formatters.py", line 221, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\formatters.py", line 338, in __call__
#     return printer(obj)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\pylabtools.py", line 152, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\backend_bases.py", line 2295, in print_figure
#     self.figure.draw(renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 74, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\figure.py", line 2845, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\image.py", line 132, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\axes\_base.py", line 3091, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\image.py", line 132, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\collections.py", line 2175, in draw
#     self.update_scalarmappable()
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\collections.py", line 905, in update_scalarmappable
#     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\cm.py", line 455, in to_rgba
#     x = self.norm(x)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\colors.py", line 1236, in __call__
#     result, is_scalar = self.process_value(value)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\matplotlib\colors.py", line 1212, in process_value
#     result = np.ma.array(data, mask=mask, dtype=dtype, copy=True)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\numpy\ma\core.py", line 6562, in array
#     return MaskedArray(data, mask=mask, dtype=dtype, copy=copy,
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\numpy\ma\core.py", line 2826, in __new__
#     _data = np.array(data, dtype=dtype, copy=copy,
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 521. KiB for an array with shape (133250,) and data type float32
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 793, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\IPython\core\ultratb.py", line 848, in get_records
#     return list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 583, in stack_data
#     yield from collapse_repeated(
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 573, in mapper
#     return cls(f, options)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\stack_data\core.py", line 537, in __init__
#     self.executing = Source.executing(frame_or_tb)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 359, in executing
#     source = cls.for_frame(frame)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 277, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 306, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 317, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\site-packages\executing\executing.py", line 257, in __init__
#     self.tree = ast.parse(ast_text, filename=filename)
#   File "C:\Users\abs\anaconda3\envs\audio-project\lib\ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
# MemoryError

# %%
import soundfile
import os

def convertTo16Bit(directory):
    for file in os.listdir(directory):
         if(file.endswith('.wav')):
                nameSolo = file.rsplit('.', 1)[0]
                path = directory + '/' + file
                #print(directory + f'/{nameSolo}')
                data, samplerate = soundfile.read(path)

                soundfile.write('dataset/TIGER-16bit/' + nameSolo + '_16BIT.wav', data, samplerate, subtype='PCM_16')
                #print("converting " + file + "to 16 - bit")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abs\\Documents\\ml-audio'

# %%
convertTo16Bit('dataset/TIGER')
